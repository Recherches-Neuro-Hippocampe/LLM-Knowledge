# %% [markdown]
# # OMC-ETL-Agent
# ## This notebook collects all informtion required for omc-etl sql agent project

# %% [markdown]
# ## 1. Ideas for fuzzy match
# ### 1.1 Existing fuzzy match libraries
# Store constant values like cities, gender, provinces, etc and fuzzy match user queries with these values. Find and replace occurences to help limit typos or alternative spellings/short forms.
#
# ### 1.2 Semantic search
# #### 1.2.1 Embedding
# An embedding is a relatively low-dimensional space into which you can translate high-dimensional vectors. Embeddings make it easier to do machine learning on large inputs like sparse vectors representing words. Ideally, an embedding captures some of the semantics of the input by placing semantically similar inputs close together in the embedding space. An embedding can be learned and reused across models.
#
# Here is an example for what embedding layer actual does: It clusters the semantically cloesed entries.
#
# ![image.png](attachment:image.png)
#
# #### 1.2.2 Semantic search with embedding
# We can use pretained embedding to project the user's query into a lower dimension space (like a vector), we apply the same process to the database attributes and we extract the ones with the cloest distane (or highest cosine similarity score).
#
# The above procedure will look like this [repo](https://github.com/openai/openai-cookbook/blob/main/examples/Semantic_text_search_using_embeddings.ipynb)

# %% [markdown]
# ## 2.  Sanitize
#
# A tool that we can use is the [Moderation API](https://platform.openai.com/docs/guides/moderation/overview) from openai.

# %% [markdown]
# ## 3. SQL Agent
#
# * [SQL database agent](https://python.langchain.com/en/latest/modules/agents/toolkits/examples/sql_database.html)
#
# * [SQL chain](https://python.langchain.com/en/latest/modules/chains/examples/sqlite.html)
#
# * [source code to create_sql_agent](https://github.com/hwchase17/langchain/blob/master/langchain/agents/agent_toolkits/sql/base.py)
#
# * [powerBI database agent](https://python.langchain.com/en/latest/modules/agents/toolkits/examples/powerbi.html)
